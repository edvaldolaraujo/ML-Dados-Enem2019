# %% [markdown]
# # Notas do Enem
# ## Experimento Supervisionado
# ### Tarefa Regressão

# %%
import pandas as pd

# %%
enem2019 = pd.read_csv("C:/Sandbox/MICRODADOS_ENEM_2019_redacao_ok.csv",  encoding = "ISO-8859-1", sep=',')

# %%
enem2019.head()
# Out:
#    Unnamed: 0  NU_INSCRICAO  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 0           0  190001004627                15               PA        21
# 1           1  190001004628                15               PA        16
# 2           2  190001004629                15               PA        18
# 3           3  190001004632                15               PA        31
# 4           4  190001004633                15               PA        30
#
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  \
# 0       M                1            3                 4                1
# 1       F                1            3                 1                3
# 2       F                1            1                 1                2
# 3       M                1            1                 1                1
# 4       F                2            3                 1                1
#
#    ...  Q016  Q017  Q018  Q019  Q020  Q021  Q022  Q023  Q024  Q025
# ...

# %%
corr = enem2019.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
# ...

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\edval\anaconda3\envs\mldev\lib\site-packages\pandas\io\formats\style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\edval\anaconda3\envs\mldev\lib\site-packages\pandas\io\formats\style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# ...
