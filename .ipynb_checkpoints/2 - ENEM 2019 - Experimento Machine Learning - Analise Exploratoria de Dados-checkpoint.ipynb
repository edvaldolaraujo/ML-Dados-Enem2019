# %% [markdown]
# # ENEM 2019 - Experimento Machine Learning - Análise Exploratória de Dados (Dados Categóricos)

# %% [markdown]
# ## Análise Exploratória de Dados
# Esta é uma técnica inicial muito comum e, ao mesmo tempo, essencial para qualquer trabalho de machine learning.
#
# O objetivo é entender como os dados estão organizados, conhecer cada **feature** em termos de distribuição, presença de dados **missing**, **outliers** e medidas estatisticas que detalhem melhor os dados.

# %% [markdown]
# ### Carregando o conjunto de dados e avaliando a estrutura

# %%
import pandas as pd

# %% [markdown]
# ### Explorando os dados da nota da redação
# Após o pré-processamento temos agora uma base com 53 colunas (uma redução de 61% no número) e cerca de 3,7M de casos (aproximadamente 73% do conjunto original).
#
# Agora o passo seguinte é explorar as variáveis do conjunto de dados.
#
# Para este conjunto ajustado consideraremos a coluna `NU_NOTA_REDACAO` como variável **dependente**. Esta definição é importante, pois os algorítmos de classificação e regressão necessitam desta variável.

# %%
enem2019_dados = pd.read_csv("C:/Sandbox/MICRODADOS_ENEM_2019_interim.csv",  encoding = "ISO-8859-1", sep=',')

# %% [markdown]
# Transformando dados string em categorias

# %%
categoricos = ['SG_UF_RESIDENCIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO', 
               'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC',
               'TP_SIT_FUNC_ESC', 'TP_LINGUA', 'TP_STATUS_REDACAO', 
               'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015',
               'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'
              ]

for campos in categoricos:
    enem2019_dados[campos] = enem2019_dados[campos].astype("category")

# %% [markdown]
# Sumário estatístico para entender os grandes números relacionados a `NU_NOTA_REDACAO`

# %%
(enem2019_dados['NU_NOTA_REDACAO'].describe())
# Out:
# count    3.702007e+06
# mean     5.797694e+02
# std      1.825116e+02
# min      0.000000e+00
# 25%      5.000000e+02
# 50%      5.800000e+02
# 75%      6.800000e+02
# max      1.000000e+03
# Name: NU_NOTA_REDACAO, dtype: float64

# %% [markdown]
# No ENEM 2019 a média das notas ficou em torno de **580 pontos** com um desvio padrão de **183 pontos**.
# O desvio padrão é um indicativo de quão espalhados os dados estão em relação a média.

# %% [markdown]
# Uma análise de distribuição permitirá entender como as notas estão distribuídas dentro do intervalo [0,1000]. Também será possivel avaliar se há assimetria e entender como as notas se comportam nos estremos deste intervalor.

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))

fig.suptitle('Análise de distribuição: NU_NOTA_REDACAO')

axs[0].set_title('Distribuição de Frequência')
axs[0].hist(enem2019_dados['NU_NOTA_REDACAO'],  bins=10)
axs[1].set_title('Distribuição Empírica')
axs[1].boxplot(enem2019_dados['NU_NOTA_REDACAO'])

plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(enem2019_dados['NU_NOTA_REDACAO'])
# Out:
# C:\Users\edval\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NU_NOTA_REDACAO', ylabel='Density'>

# %% [markdown]
# Em tese, as notas da redação poderiam seguir uma distribuição normal, mas não é o que vemos na prática. Os extremos tem um comportamento peculiar principalmente nas notas que estão entre o intervalo [0,200].

# %% [markdown]
# Um descritivo estatístico da variável `NU_NOTA_REDACAO´ ajudará a entender aspectos relacionados com a distribuição e distribuição das notas

# %%
import statsmodels.api as sm
import statsmodels.stats.descriptivestats as smdesc

# %%
smdesc.describe(data=enem2019_dados['NU_NOTA_REDACAO'], stats=['nobs', 'median', 'mode', 'mean', 
                                                               'std', 'ci', 'skew', 'kurtosis'], 
                alpha=0.05)
# Out:
#            NU_NOTA_REDACAO
# nobs          3.702007e+06
# mean          5.797694e+02
# upper_ci      5.797695e+02
# lower_ci      5.797693e+02
# std           1.825116e+02
# skew         -6.327232e-01
# kurtosis      4.464667e+00
# mode          6.000000e+02
# mode_freq     7.168733e-02
# median        5.800000e+02

# %% [markdown]
# A nota da redação tem uma pequena assimetria negativa devido ao fato da mdia ser um pouco maior que a média. Outro ponto é a curtose positiva o que significa que o pico é maior do que o observado em uma distribuição normal.

# %% [markdown]
# Por fim, um gráfico QQ-Plot ajudará entender se a nota da prova se aproxima de uma curva normal.

# %%
from scipy import stats

# %%
stats.probplot(enem2019_dados['NU_NOTA_REDACAO'], plot=plt)
plt.show()

# %% [markdown]
# Como observado anteriormente há desvios percebidos nos extremos da distribuição. Com isso não podemos afirmar que a nota da redação tem uma distribuição normal.
#
# Não vamos remover as notas nas extremidades, pois é do interesse desse experimento entender as notas e isto implica levar em consideração os casos extremos.

# %% [markdown]
# ### Explorando os dados categóricos

# %%
enem2019_dados.head(5)
# Out:
#    NU_INSCRICAO  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  \
# 0  190001004627                15               PA        21       M
# 1  190001004628                15               PA        16       F
# 2  190001004629                15               PA        18       F
# 3  190001004632                15               PA        31       M
# 4  190001004633                15               PA        30       F
#
#   TP_ESTADO_CIVIL TP_COR_RACA TP_NACIONALIDADE TP_ST_CONCLUSAO  \
# 0               1           3                4               1
# 1               1           3                1               3
# 2               1           1                1               2
# 3               1           1                1               1
# 4               2           3                1               1
#
#   TP_ANO_CONCLUIU  ... Q016 Q017 Q018 Q019 Q020 Q021  Q022  Q023  Q024  Q025
# 0               3  ...    A    A    A    C    B    A     D     A     B     A
# 1               0  ...    A    A    A    B    B    A     B     A     A     A
# 2               0  ...    B    A    A    D    B    B     D     A     C     B
# 3               7  ...    A    A    A    B    A    A     D     A     A     A
# 4              10  ...    A    A    A    B    A    A     B     A     A     B
#
# [5 rows x 53 columns]

# %%
def Explorar(var_indep, var_dep, df, freq=False, media=False):
    print()
    print('=======================')
    print('Explorando:', var_indep, '(n=', df[var_indep].count(), ')')
    print('=======================')
    if freq:
        print('Freq. Relativa',df.groupby(var_indep)[var_indep].count()/df.shape[0]*100)
        print()
    if media:
        print('Média de ', var_dep, '(', df[var_dep].mean(), ') por ', df.groupby(var_indep).mean()[var_dep])
        print()

# %%
for campos in categoricos:
    Explorar(var_indep=campos, var_dep='NU_NOTA_REDACAO', df=enem2019_dados, freq=True)
# Out:
# =======================
# Explorando: SG_UF_RESIDENCIA (n= 3702007 )
# =======================
# Freq. Relativa SG_UF_RESIDENCIA
# AC     0.732927
# AL     1.857101
# AM     2.012044
# AP     0.798270
# BA     7.812762
# CE     5.994532
# DF     1.801968
# ES     1.954832
# GO     3.341998
# MA     4.431353
# MG    10.618483
# MS     1.316880
# MT     1.633465
# PA     5.613361
# PB     3.080653
# PE     5.476840
# PI     2.545619
# PR     4.064336
# RJ     6.600204
# RN     2.441459
# RO     1.104266
# RR     0.237682
# RS     4.215497
# SC     2.137624
# SE     1.563611
# SP    15.699160
# TO     0.913072
# Name: SG_UF_RESIDENCIA, dtype: float64
#
#
# =======================
# Explorando: TP_SEXO (n= 3702007 )
# =======================
# Freq. Relativa TP_SEXO
# F    59.460071
# M    40.539929
# Name: TP_SEXO, dtype: float64
#
#
# =======================
# Explorando: TP_ESTADO_CIVIL (n= 3702007 )
# =======================
# Freq. Relativa TP_ESTADO_CIVIL
# 0     3.498913
# 1    88.958611
# 2     6.037293
# 3     1.404076
# 4     0.101107
# Name: TP_ESTADO_CIVIL, dtype: float64
#
#
# =======================
# Explorando: TP_COR_RACA (n= 3702007 )
# =======================
# Freq. Relativa TP_COR_RACA
# 0     1.983654
# 1    37.139557
# 2    12.242629
# 3    45.763339
# 4     2.289434
# 5     0.581387
# Name: TP_COR_RACA, dtype: float64
#
#
# =======================
# Explorando: TP_NACIONALIDADE (n= 3702007 )
# =======================
# Freq. Relativa TP_NACIONALIDADE
# 0     0.135683
# 1    97.131367
# 2     2.443593
# 3     0.113884
# 4     0.175472
# Name: TP_NACIONALIDADE, dtype: float64
#
#
# =======================
# Explorando: TP_ST_CONCLUSAO (n= 3702007 )
# =======================
# Freq. Relativa TP_ST_CONCLUSAO
# 1    52.583747
# 2    32.878247
# 3    14.254403
# 4     0.283603
# Name: TP_ST_CONCLUSAO, dtype: float64
#
#
# =======================
# Explorando: TP_ANO_CONCLUIU (n= 3702007 )
# =======================
# Freq. Relativa TP_ANO_CONCLUIU
# 0     49.122679
# 1     13.219505
# 2      8.439584
# 3      5.577002
# 4      4.038674
# 5      3.077115
# 6      2.358369
# 7      1.952157
# 8      1.508992
# 9      1.357021
# 10     1.184358
# 11     0.971203
# 12     0.895460
# 13     6.297881
# Name: TP_ANO_CONCLUIU, dtype: float64
#
#
# =======================
# Explorando: TP_ESCOLA (n= 3702007 )
# =======================
# Freq. Relativa TP_ESCOLA
# 1    67.121780
# 2    27.278501
# 3     5.599719
# Name: TP_ESCOLA, dtype: float64
#
#
# =======================
# Explorando: TP_ENSINO (n= 3702007 )
# =======================
# Freq. Relativa TP_ENSINO
# 0.0    42.729957
# 1.0    57.032010
# 2.0     0.238033
# Name: TP_ENSINO, dtype: float64
#
#
# =======================
# Explorando: IN_TREINEIRO (n= 3702007 )
# =======================
# Freq. Relativa IN_TREINEIRO
# 0    85.745597
# 1    14.254403
# Name: IN_TREINEIRO, dtype: float64
#
#
# =======================
# Explorando: TP_DEPENDENCIA_ADM_ESC (n= 3702007 )
# =======================
# Freq. Relativa TP_DEPENDENCIA_ADM_ESC
# 0.0    74.232572
# 1.0     1.260938
# 2.0    20.081215
# 3.0     0.212209
# 4.0     4.213066
# Name: TP_DEPENDENCIA_ADM_ESC, dtype: float64
#
#
# =======================
# Explorando: TP_LOCALIZACAO_ESC (n= 3702007 )
# =======================
# Freq. Relativa TP_LOCALIZACAO_ESC
# 0.0    74.232572
# 1.0    24.873886
# 2.0     0.893542
# Name: TP_LOCALIZACAO_ESC, dtype: float64
#
#
# =======================
# Explorando: TP_SIT_FUNC_ESC (n= 3702007 )
# =======================
# Freq. Relativa TP_SIT_FUNC_ESC
# 0.0    74.232572
# 1.0    25.695900
# 2.0     0.028417
# 3.0     0.004727
# 4.0     0.038385
# Name: TP_SIT_FUNC_ESC, dtype: float64
#
#
# =======================
# Explorando: TP_LINGUA (n= 3702007 )
# =======================
# Freq. Relativa TP_LINGUA
# 0    49.630187
# 1    50.369813
# Name: TP_LINGUA, dtype: float64
#
#
# =======================
# Explorando: TP_STATUS_REDACAO (n= 3702007 )
# =======================
# Freq. Relativa TP_STATUS_REDACAO
# 1.0    97.139660
# 2.0     0.133171
# 3.0     0.563424
# 4.0     0.948107
# 6.0     0.846190
# 7.0     0.091842
# 8.0     0.167261
# 9.0     0.110346
# Name: TP_STATUS_REDACAO, dtype: float64
#
#
# =======================
# Explorando: Q001 (n= 3702007 )
# =======================
# Freq. Relativa Q001
# A     5.029326
# B    20.328514
# C    13.932578
# D    11.701572
# E    27.181337
# F     8.328428
# G     5.227678
# H     8.270568
# Name: Q001, dtype: float64
#
#
# =======================
# Explorando: Q002 (n= 3702007 )
# =======================
# Freq. Relativa Q002
# A     3.269092
# B    14.897757
# C    12.745168
# D    12.852002
# E    33.354178
# F    11.245008
# G     8.999416
# H     2.637380
# Name: Q002, dtype: float64
#
#
# =======================
# Explorando: Q003 (n= 3702007 )
# =======================
# Freq. Relativa Q003
# A    20.359065
# B    20.447989
# C    23.360869
# D    18.760337
# E     6.215088
# F    10.856652
# Name: Q003, dtype: float64
#
#
# =======================
# Explorando: Q004 (n= 3702007 )
# =======================
# Freq. Relativa Q004
# A    16.548564
# B    41.723989
# C     6.750582
# D    22.159683
# E     4.289646
# F     8.527537
# Name: Q004, dtype: float64
#
#
# =======================
# Explorando: Q006 (n= 3702007 )
# =======================
# Freq. Relativa Q006
# A     4.270467
# B    24.104249
# C    24.446361
# D     9.639879
# E     9.346120
# F     4.651369
# G     6.328945
# H     4.180759
# I     3.186299
# J     1.803265
# K     1.310613
# L     0.994001
# M     0.975093
# N     1.395162
# O     1.132251
# P     0.974796
# Q     1.260370
# Name: Q006, dtype: float64
#
#
# =======================
# Explorando: Q007 (n= 3702007 )
# =======================
# Freq. Relativa Q007
# A    92.100636
# B     4.181894
# C     0.896163
# D     2.821307
# Name: Q007, dtype: float64
#
#
# =======================
# Explorando: Q008 (n= 3702007 )
# =======================
# Freq. Relativa Q008
# A     0.911614
# B    67.983205
# C    21.732995
# D     6.153014
# E     3.219173
# Name: Q008, dtype: float64
#
#
# =======================
# Explorando: Q009 (n= 3702007 )
# =======================
# Freq. Relativa Q009
# A     0.713721
# B    11.956190
# C    49.863709
# D    32.143888
# E     5.322491
# Name: Q009, dtype: float64
#
#
# =======================
# Explorando: Q010 (n= 3702007 )
# =======================
# Freq. Relativa Q010
# A    54.027099
# B    36.271811
# C     8.327510
# D     1.133412
# E     0.240167
# Name: Q010, dtype: float64
#
#
# =======================
# Explorando: Q011 (n= 3702007 )
# =======================
# Freq. Relativa Q011
# A    77.157688
# B    20.596936
# C     2.014745
# D     0.194597
# E     0.036035
# Name: Q011, dtype: float64
#
#
# =======================
# Explorando: Q012 (n= 3702007 )
# =======================
# Freq. Relativa Q012
# A     1.589300
# B    93.804928
# C     4.248911
# D     0.300053
# E     0.056807
# Name: Q012, dtype: float64
#
#
# =======================
# Explorando: Q013 (n= 3702007 )
# =======================
# Freq. Relativa Q013
# A    61.725059
# B    35.470165
# C     2.446268
# D     0.290383
# E     0.068125
# Name: Q013, dtype: float64
#
#
# =======================
# Explorando: Q014 (n= 3702007 )
# =======================
# Freq. Relativa Q014
# A    39.645576
# B    59.380277
# C     0.928848
# D     0.036278
# E     0.009022
# Name: Q014, dtype: float64
#
#
# =======================
# Explorando: Q015 (n= 3702007 )
# =======================
# Freq. Relativa Q015
# A    88.038515
# B    11.814834
# C     0.130200
# D     0.010346
# E     0.006105
# Name: Q015, dtype: float64
#
#
# =======================
# Explorando: Q016 (n= 3702007 )
# =======================
# Freq. Relativa Q016
# A    49.356417
# B    50.090046
# C     0.520393
# D     0.025257
# E     0.007888
# Name: Q016, dtype: float64
#
#
# =======================
# Explorando: Q017 (n= 3702007 )
# =======================
# Freq. Relativa Q017
# A    97.337660
# B     2.613852
# C     0.035926
# D     0.007401
# E     0.005159
# Name: Q017, dtype: float64
#
#
# =======================
# Explorando: Q018 (n= 3702007 )
# =======================
# Freq. Relativa Q018
# A    79.207873
# B    20.792127
# Name: Q018, dtype: float64
#
#
# =======================
# Explorando: Q019 (n= 3702007 )
# =======================
# Freq. Relativa Q019
# A     4.508311
# B    67.295443
# C    18.955151
# D     6.332781
# E     2.908314
# Name: Q019, dtype: float64
#
#
# =======================
# Explorando: Q020 (n= 3702007 )
# =======================
# Freq. Relativa Q020
# A    68.242307
# B    31.757693
# Name: Q020, dtype: float64
#
#
# =======================
# Explorando: Q021 (n= 3702007 )
# =======================
# Freq. Relativa Q021
# A    76.534485
# B    23.465515
# Name: Q021, dtype: float64
#
#
# =======================
# Explorando: Q022 (n= 3702007 )
# =======================
# Freq. Relativa Q022
# A     2.074631
# B    19.505204
# C    29.999160
# D    28.657914
# E    19.763091
# Name: Q022, dtype: float64
#
#
# =======================
# Explorando: Q023 (n= 3702007 )
# =======================
# Freq. Relativa Q023
# A    74.820253
# B    25.179747
# Name: Q023, dtype: float64
#
#
# =======================
# Explorando: Q024 (n= 3702007 )
# =======================
# Freq. Relativa Q024
# A    43.829388
# B    44.213477
# C     8.336289
# D     2.557613
# E     1.063234
# Name: Q024, dtype: float64
#
#
# =======================
# Explorando: Q025 (n= 3702007 )
# =======================
# Freq. Relativa Q025
# A    21.123029
# B    78.876971
# Name: Q025, dtype: float64

# %% [markdown]
# A frequência relativa das variáveis categóricas permite entender mais a respeito do perfil dos participantes. Durante esta avaliação podemos identificar que algumas variaveis podem ser excluidas do conjunto de dados.
#
# Duas são as razões para tal exclusão:
# 1. Variáveis consideradas irrelevantes para o experimento
# 2. Presença do tipo de resposta **Não Respondeu** dificulta qualquer análise ou conclusão a partir de tal informação.
#
# A tabela abaixo apresenta as variáveis agrupadas por razão:
#
# |Razão 1   | Razão 2  |
# |:---------|:---------|
# |TP_ESTADO_CIVIL |TP_ESCOLA |
# |TP_NACIONALIDADE | TP_ENSINO |
# |TP_ST_CONCLUSAO | |
# |TP_ANO_CONCLUIU | |
# |IN_TREINEIRO | |
# |TP_DEPENDENCIA_ADM_ESC | |
# |TP_LOCALIZACAO_ESC | |
# |TP_SIT_FUNC_ESC | |
# |TP_LINGUA | |
# |TP_STATUS_REDACAO | |

# %%
remover = ['TP_ESTADO_CIVIL', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 
           'IN_TREINEIRO', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'TP_LINGUA', 'TP_STATUS_REDACAO']

enem2019_dados.drop(columns=remover, inplace=True)

# %% [markdown]
# Frequência sem as colunas removidas

# %%
for itens in remover:
    categoricos.remove(itens) 

for campos in categoricos:
    Explorar(var_indep=campos, var_dep='NU_NOTA_REDACAO', df=enem2019_dados, freq=True)
# Out:
# =======================
# Explorando: SG_UF_RESIDENCIA (n= 3702007 )
# =======================
# Freq. Relativa SG_UF_RESIDENCIA
# AC     0.732927
# AL     1.857101
# AM     2.012044
# AP     0.798270
# BA     7.812762
# CE     5.994532
# DF     1.801968
# ES     1.954832
# GO     3.341998
# MA     4.431353
# MG    10.618483
# MS     1.316880
# MT     1.633465
# PA     5.613361
# PB     3.080653
# PE     5.476840
# PI     2.545619
# PR     4.064336
# RJ     6.600204
# RN     2.441459
# RO     1.104266
# RR     0.237682
# RS     4.215497
# SC     2.137624
# SE     1.563611
# SP    15.699160
# TO     0.913072
# Name: SG_UF_RESIDENCIA, dtype: float64
#
#
# =======================
# Explorando: TP_SEXO (n= 3702007 )
# =======================
# Freq. Relativa TP_SEXO
# F    59.460071
# M    40.539929
# Name: TP_SEXO, dtype: float64
#
#
# =======================
# Explorando: TP_COR_RACA (n= 3702007 )
# =======================
# Freq. Relativa TP_COR_RACA
# 0     1.983654
# 1    37.139557
# 2    12.242629
# 3    45.763339
# 4     2.289434
# 5     0.581387
# Name: TP_COR_RACA, dtype: float64
#
#
# =======================
# Explorando: Q001 (n= 3702007 )
# =======================
# Freq. Relativa Q001
# A     5.029326
# B    20.328514
# C    13.932578
# D    11.701572
# E    27.181337
# F     8.328428
# G     5.227678
# H     8.270568
# Name: Q001, dtype: float64
#
#
# =======================
# Explorando: Q002 (n= 3702007 )
# =======================
# Freq. Relativa Q002
# A     3.269092
# B    14.897757
# C    12.745168
# D    12.852002
# E    33.354178
# F    11.245008
# G     8.999416
# H     2.637380
# Name: Q002, dtype: float64
#
#
# =======================
# Explorando: Q003 (n= 3702007 )
# =======================
# Freq. Relativa Q003
# A    20.359065
# B    20.447989
# C    23.360869
# D    18.760337
# E     6.215088
# F    10.856652
# Name: Q003, dtype: float64
#
#
# =======================
# Explorando: Q004 (n= 3702007 )
# =======================
# Freq. Relativa Q004
# A    16.548564
# B    41.723989
# C     6.750582
# D    22.159683
# E     4.289646
# F     8.527537
# Name: Q004, dtype: float64
#
#
# =======================
# Explorando: Q006 (n= 3702007 )
# =======================
# Freq. Relativa Q006
# A     4.270467
# B    24.104249
# C    24.446361
# D     9.639879
# E     9.346120
# F     4.651369
# G     6.328945
# H     4.180759
# I     3.186299
# J     1.803265
# K     1.310613
# L     0.994001
# M     0.975093
# N     1.395162
# O     1.132251
# P     0.974796
# Q     1.260370
# Name: Q006, dtype: float64
#
#
# =======================
# Explorando: Q007 (n= 3702007 )
# =======================
# Freq. Relativa Q007
# A    92.100636
# B     4.181894
# C     0.896163
# D     2.821307
# Name: Q007, dtype: float64
#
#
# =======================
# Explorando: Q008 (n= 3702007 )
# =======================
# Freq. Relativa Q008
# A     0.911614
# B    67.983205
# C    21.732995
# D     6.153014
# E     3.219173
# Name: Q008, dtype: float64
#
#
# =======================
# Explorando: Q009 (n= 3702007 )
# =======================
# Freq. Relativa Q009
# A     0.713721
# B    11.956190
# C    49.863709
# D    32.143888
# E     5.322491
# Name: Q009, dtype: float64
#
#
# =======================
# Explorando: Q010 (n= 3702007 )
# =======================
# Freq. Relativa Q010
# A    54.027099
# B    36.271811
# C     8.327510
# D     1.133412
# E     0.240167
# Name: Q010, dtype: float64
#
#
# =======================
# Explorando: Q011 (n= 3702007 )
# =======================
# Freq. Relativa Q011
# A    77.157688
# B    20.596936
# C     2.014745
# D     0.194597
# E     0.036035
# Name: Q011, dtype: float64
#
#
# =======================
# Explorando: Q012 (n= 3702007 )
# =======================
# Freq. Relativa Q012
# A     1.589300
# B    93.804928
# C     4.248911
# D     0.300053
# E     0.056807
# Name: Q012, dtype: float64
#
#
# =======================
# Explorando: Q013 (n= 3702007 )
# =======================
# Freq. Relativa Q013
# A    61.725059
# B    35.470165
# C     2.446268
# D     0.290383
# E     0.068125
# Name: Q013, dtype: float64
#
#
# =======================
# Explorando: Q014 (n= 3702007 )
# =======================
# Freq. Relativa Q014
# A    39.645576
# B    59.380277
# C     0.928848
# D     0.036278
# E     0.009022
# Name: Q014, dtype: float64
#
#
# =======================
# Explorando: Q015 (n= 3702007 )
# =======================
# Freq. Relativa Q015
# A    88.038515
# B    11.814834
# C     0.130200
# D     0.010346
# E     0.006105
# Name: Q015, dtype: float64
#
#
# =======================
# Explorando: Q016 (n= 3702007 )
# =======================
# Freq. Relativa Q016
# A    49.356417
# B    50.090046
# C     0.520393
# D     0.025257
# E     0.007888
# Name: Q016, dtype: float64
#
#
# =======================
# Explorando: Q017 (n= 3702007 )
# =======================
# Freq. Relativa Q017
# A    97.337660
# B     2.613852
# C     0.035926
# D     0.007401
# E     0.005159
# Name: Q017, dtype: float64
#
#
# =======================
# Explorando: Q018 (n= 3702007 )
# =======================
# Freq. Relativa Q018
# A    79.207873
# B    20.792127
# Name: Q018, dtype: float64
#
#
# =======================
# Explorando: Q019 (n= 3702007 )
# =======================
# Freq. Relativa Q019
# A     4.508311
# B    67.295443
# C    18.955151
# D     6.332781
# E     2.908314
# Name: Q019, dtype: float64
#
#
# =======================
# Explorando: Q020 (n= 3702007 )
# =======================
# Freq. Relativa Q020
# A    68.242307
# B    31.757693
# Name: Q020, dtype: float64
#
#
# =======================
# Explorando: Q021 (n= 3702007 )
# =======================
# Freq. Relativa Q021
# A    76.534485
# B    23.465515
# Name: Q021, dtype: float64
#
#
# =======================
# Explorando: Q022 (n= 3702007 )
# =======================
# Freq. Relativa Q022
# A     2.074631
# B    19.505204
# C    29.999160
# D    28.657914
# E    19.763091
# Name: Q022, dtype: float64
#
#
# =======================
# Explorando: Q023 (n= 3702007 )
# =======================
# Freq. Relativa Q023
# A    74.820253
# B    25.179747
# Name: Q023, dtype: float64
#
#
# =======================
# Explorando: Q024 (n= 3702007 )
# =======================
# Freq. Relativa Q024
# A    43.829388
# B    44.213477
# C     8.336289
# D     2.557613
# E     1.063234
# Name: Q024, dtype: float64
#
#
# =======================
# Explorando: Q025 (n= 3702007 )
# =======================
# Freq. Relativa Q025
# A    21.123029
# B    78.876971
# Name: Q025, dtype: float64

# %% [markdown]
# As colunas Q001 até Q025 são informações referentes ao questionário socioeconômico. Algunas destas informações, provalvemente, não ajudam a explicar a performance da nota de redação, mas são importantes para entender um pouco mais a respeito dos participantes.
#
# Em função disso, na proxima seção, faremos dois exercicios para entender o que pode ser feito com estas variáveis:
# * Análise de agrupamentos
# * Redução de dimensionalidade
#
# Ambos são técnicas de aprendizado supervisionado e nos ajudarão a definir o que pode ser feito com todas estas colunas.
#
# Enquanto isso olharemos as demais variáveis categóricas comparando as categorias com as notas médias de redação.

# %%
Q000 = ['Q001','Q002','Q003','Q004','Q006','Q007','Q008','Q009','Q010','Q011','Q012','Q013','Q014','Q015','Q016','Q017',
        'Q018','Q019','Q020','Q021','Q022','Q023','Q024','Q025']

for q0 in Q000:
    categoricos.remove(q0) 

for campos in categoricos:
    Explorar(var_indep=campos, var_dep='NU_NOTA_REDACAO', df=enem2019_dados, freq=True, media=True)
# Out:
# =======================
# Explorando: SG_UF_RESIDENCIA (n= 3702007 )
# =======================
# Freq. Relativa SG_UF_RESIDENCIA
# AC     0.732927
# AL     1.857101
# AM     2.012044
# AP     0.798270
# BA     7.812762
# CE     5.994532
# DF     1.801968
# ES     1.954832
# GO     3.341998
# MA     4.431353
# MG    10.618483
# MS     1.316880
# MT     1.633465
# PA     5.613361
# PB     3.080653
# PE     5.476840
# PI     2.545619
# PR     4.064336
# RJ     6.600204
# RN     2.441459
# RO     1.104266
# RR     0.237682
# RS     4.215497
# SC     2.137624
# SE     1.563611
# SP    15.699160
# TO     0.913072
# Name: SG_UF_RESIDENCIA, dtype: float64
#
# Média de  NU_NOTA_REDACAO ( 579.7694061626572 ) por  SG_UF_RESIDENCIA
# AC    542.830502
# AL    563.636073
# AM    518.494482
# AP    539.660937
# BA    564.112658
# CE    573.336908
# DF    595.212640
# ES    596.789465
# GO    585.617801
# MA    541.241946
# MG    605.522148
# MS    559.271400
# MT    548.730466
# PA    561.983764
# PB    581.153920
# PE    570.487440
# PI    570.322902
# PR    576.291688
# RJ    606.753131
# RN    586.318445
# RO    535.344912
# RR    531.401296
# RS    588.387138
# SC    590.894042
# SE    595.046040
# SP    596.019539
# TO    557.309035
# Name: NU_NOTA_REDACAO, dtype: float64
#
#
# =======================
# Explorando: TP_SEXO (n= 3702007 )
# =======================
# Freq. Relativa TP_SEXO
# F    59.460071
# M    40.539929
# Name: TP_SEXO, dtype: float64
#
# Média de  NU_NOTA_REDACAO ( 579.7694061626572 ) por  TP_SEXO
# F    585.603494
# M    571.212527
# Name: NU_NOTA_REDACAO, dtype: float64
#
#
# =======================
# Explorando: TP_COR_RACA (n= 3702007 )
# =======================
# Freq. Relativa TP_COR_RACA
# 0     1.983654
# 1    37.139557
# 2    12.242629
# 3    45.763339
# 4     2.289434
# 5     0.581387
# Name: TP_COR_RACA, dtype: float64
#
# Média de  NU_NOTA_REDACAO ( 579.7694061626572 ) por  TP_COR_RACA
# 0    576.641656
# 1    615.727092
# 2    550.604978
# 3    559.689971
# 4    576.818595
# 5    499.717511
# Name: NU_NOTA_REDACAO, dtype: float64
