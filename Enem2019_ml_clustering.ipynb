# %% [markdown]
# # Notas do Enem
# ## Experimento Não-Supervisionado
# ### Tarefa Agrupamento

# %%
import pandas as pd

# %%
enem2019 = pd.read_csv("C:/Sandbox/MICRODADOS_ENEM_2019_clean.csv",  encoding = "ISO-8859-1", sep=',')

# %% [markdown]
# Comparando notas de Portugues e Matematica

# %%
enem2019.plot.scatter(x='NU_NOTA_LC', y='NU_NOTA_REDACAO')
# Out:
# <AxesSubplot:xlabel='NU_NOTA_LC', ylabel='NU_NOTA_REDACAO'>
